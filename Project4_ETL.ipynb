# %%
# Imports
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# Read in the Titanic Dataset as a dataframe
titanicDatabaseCSVPath = "Resources/titanic.csv"
titanicDF = pd.read_csv(titanicDatabaseCSVPath)

# %%
# Show the newly created dataframe
titanicDF.head(15)
# Out:
#                                         name  gender        age class  \
# 0                        Abbing, Mr. Anthony    male  42.000000   3rd
# 1                  Abbott, Mr. Eugene Joseph    male  13.000000   3rd
# 2                Abbott, Mr. Rossmore Edward    male  16.000000   3rd
# 3             Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.000000   3rd
# 4                Abelseth, Miss. Karen Marie  female  16.000000   3rd
# 5              Abelseth, Mr. Olaus Jørgensen    male  25.000000   3rd
# 6                        Abelson, Mr. Samuel    male  30.000000   2nd
# 7                       Abelson, Mrs. Hannah  female  28.000000   2nd
# 8               Abī-Al-Munà, Mr. Nāsīf Qāsim    male  27.000000   3rd
# 9   Abrahamsson, Mr. Abraham August Johannes    male  20.000000   3rd
# 10                        Ådahl, Mr. Mauritz    male  30.000000   3rd
# 11                           Adams, Mr. John    male  27.000000   3rd
# 12            Ahlin, Mrs. Johanna Persdotter  female  40.000000   3rd
# 13                 Aks, Master. Frank Philip    male   0.833333   3rd
# 14                            Aks, Mrs. Leah  female  18.000000   3rd
#
#    embarked        country   ticketno     fare  sibsp  parch survived
# 0         S  United States     5547.0   7.1100    0.0    0.0       no
# 1         S  United States     2673.0  20.0500    0.0    2.0       no
# 2         S  United States     2673.0  20.0500    1.0    1.0       no
# 3         S        England     2673.0  20.0500    1.0    1.0      yes
# 4         S         Norway   348125.0   7.1300    0.0    0.0      yes
# 5         S  United States   348122.0   7.1300    0.0    0.0      yes
# 6         C         France     3381.0  24.0000    1.0    0.0       no
# 7         C         France     3381.0  24.0000    1.0    0.0      yes
# 8         C        Lebanon     2699.0  18.1509    0.0    0.0      yes
# 9         S        Finland  3101284.0   7.1806    0.0    0.0      yes
# 10        S         Sweden     7076.0   7.0500    0.0    0.0       no
# 11        S        England   341826.0   8.0100    0.0    0.0       no
# 12        S         Sweden     7546.0   9.0906    1.0    0.0       no
# 13        S        England   392091.0   9.0700    0.0    1.0      yes
# 14        S        England   392091.0   9.0700    0.0    1.0      yes

# %%
# Change the 'C','S', 'Q's in the 'embarked' column to show the full location name
titanicDF['embarked'] = titanicDF['embarked'].map({'S': 'Southampton, England', 
                                                   'Q': 'Queenstown, Ireland', 
                                                   'C': 'Cherbourg, France'})

# %%
# Show the change
titanicDF.head()
# Out:
#                              name  gender   age class              embarked  \
# 0             Abbing, Mr. Anthony    male  42.0   3rd  Southampton, England
# 1       Abbott, Mr. Eugene Joseph    male  13.0   3rd  Southampton, England
# 2     Abbott, Mr. Rossmore Edward    male  16.0   3rd  Southampton, England
# 3  Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0   3rd  Southampton, England
# 4     Abelseth, Miss. Karen Marie  female  16.0   3rd  Southampton, England
#
#          country  ticketno   fare  sibsp  parch survived
# 0  United States    5547.0   7.11    0.0    0.0       no
# 1  United States    2673.0  20.05    0.0    2.0       no
# 2  United States    2673.0  20.05    1.0    1.0       no
# 3        England    2673.0  20.05    1.0    1.0      yes
# 4         Norway  348125.0   7.13    0.0    0.0      yes

# %%
# Split the 'Name' column by comma into two new columns: 'Last Name' and 'First Name'
titanicDF[['last name', 'first name']] = titanicDF['name'].str.split(',', n=1, expand=True)

# Strip any leading/trailing whitespace from the names
titanicDF['last name'] = titanicDF['last name'].str.strip()
titanicDF['first name'] = titanicDF['first name'].str.strip()

# Drop the name column
titanicDF = titanicDF.drop(columns=['name'])

titanicDF.head(20)
# Out:
#     gender        age class              embarked        country   ticketno  \
# 0     male  42.000000   3rd  Southampton, England  United States     5547.0
# 1     male  13.000000   3rd  Southampton, England  United States     2673.0
# 2     male  16.000000   3rd  Southampton, England  United States     2673.0
# 3   female  39.000000   3rd  Southampton, England        England     2673.0
# 4   female  16.000000   3rd  Southampton, England         Norway   348125.0
# 5     male  25.000000   3rd  Southampton, England  United States   348122.0
# 6     male  30.000000   2nd     Cherbourg, France         France     3381.0
# 7   female  28.000000   2nd     Cherbourg, France         France     3381.0
# 8     male  27.000000   3rd     Cherbourg, France        Lebanon     2699.0
# 9     male  20.000000   3rd  Southampton, England        Finland  3101284.0
# 10    male  30.000000   3rd  Southampton, England         Sweden     7076.0
# 11    male  27.000000   3rd  Southampton, England        England   341826.0
# 12  female  40.000000   3rd  Southampton, England         Sweden     7546.0
# 13    male   0.833333   3rd  Southampton, England        England   392091.0
# 14  female  18.000000   3rd  Southampton, England        England   392091.0
# 15    male  35.000000   2nd  Southampton, England        England   248744.0
# 16    male  25.000000   3rd  Southampton, England        England     3474.0
# 17    male  19.000000   3rd  Southampton, England        Finland  3101287.0
# 18    male  24.000000   3rd  Southampton, England      Argentina  3101311.0
# 19    male  25.000000   3rd  Southampton, England      Argentina  3101312.0
#
#        fare  sibsp  parch survived    last name                   first name
# 0    7.1100    0.0    0.0       no       Abbing                  Mr. Anthony
# 1   20.0500    0.0    2.0       no       Abbott            Mr. Eugene Joseph
# 2   20.0500    1.0    1.0       no       Abbott          Mr. Rossmore Edward
# 3   20.0500    1.0    1.0      yes       Abbott       Mrs. Rhoda Mary 'Rosa'
# 4    7.1300    0.0    0.0      yes     Abelseth            Miss. Karen Marie
# 5    7.1300    0.0    0.0      yes     Abelseth          Mr. Olaus Jørgensen
# 6   24.0000    1.0    0.0       no      Abelson                   Mr. Samuel
# 7   24.0000    1.0    0.0      yes      Abelson                  Mrs. Hannah
# 8   18.1509    0.0    0.0      yes  Abī-Al-Munà              Mr. Nāsīf Qāsim
# 9    7.1806    0.0    0.0      yes  Abrahamsson  Mr. Abraham August Johannes
# 10   7.0500    0.0    0.0       no        Ådahl                  Mr. Mauritz
# 11   8.0100    0.0    0.0       no        Adams                     Mr. John
# 12   9.0906    1.0    0.0       no        Ahlin      Mrs. Johanna Persdotter
# 13   9.0700    0.0    1.0      yes          Aks         Master. Frank Philip
# 14   9.0700    0.0    1.0      yes          Aks                    Mrs. Leah
# 15  13.0000    0.0    0.0       no     Aldworth           Mr. Augustus Henry
# 16   7.1709    0.0    0.0       no    Alexander           Mr. William Albert
# 17   7.1806    0.0    0.0       no     Alhomäki            Mr. Ilmari Rudolf
# 18   7.0100    0.0    0.0       no          Ali                    Mr. Ahmed
# 19   7.0100    0.0    0.0       no          Ali                  Mr. William

# %%
# Export the titanicDF as a .json file
titanicDF.to_json('titanicDF.json', orient='records')
